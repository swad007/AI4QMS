# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
import pandas as pd
file_name = 'sample_data_complaint.xlsx' 
dataset = pd.read_excel(file_name)
print(dataset.head())
# Out:
#    S No  ... Is it required to report to Authorities
# 0     1  ...                                      No
# 1     2  ...                                      No
# 2     3  ...                                      No
# 3     4  ...                                      No
# 4     5  ...                                      No
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Cleaning the texts

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 100):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Complaint Text'][i])
  review = review.lower()
  review = review.split()
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# ['leakag observ use alin seri concentr wash buffer', 'custom indic product shipment receiv warm temperatur stress therefor not suitabl use', 'shipment architect concentr wash buffer list number c lot number fn damag transit fedex refus custom', 'alin ci seri system softwar v scm westgard rule trigger two version assay instal instrument', 'custom observ bottl appear distend use architect concentr wash buffer kit', 'custom observ activ read failur error code use architect reaction vessel rv', 'custom observ microparticl bottl contain mold type deposit use architect intact pth reagent', 'custom report observ fals elev ldl hdl result patient use direct ldl reagent ln e ultra hdl reagent ln k architect system sum ldl hdl result patient greater total cholesterol result', 'custom observ multipl level non abbott control shift high use architect bnp calibr', 'assay packag insert not download system abbott mail inbox configur receiv insert norwegian languag text state assay insert english languag download system abbott mail inbox languag reconfigur english issu occur alin system scm v softwar', 'custom observ receiv troponin control lot ui bottl appear misshapen lid remov bottl return normal shape', 'complaint text state sodium result sampl id associ sampl id result not report li block rule aliniq am evalu delta check two rerun sampl id', 'custom observ fals elev vitamin result use alin vitamin reagent lot ui custom state initi result flag outsid linear repeat normal rang impact patient manag report issu resolv new reagent lot ui', 'complaint text state custom add test sampl automat rerun instrument not add instead request remain pend custom alin system softwar v instrument log not provid custom databas not avail therefor insuffici inform evalu issu', 'custom receiv bent damag probe next r unopen box consid first use failur probe next r list number r subject evalu part replac resolv issu', 'custom observ process path jam instrument step loss error use architect rv', 'auto dilut result transmit first li instead origin neat result custom alin ci system softwar v', 'custom observ low imprecis errat result calibr issu test architect free assay', 'custom perform daili mainten obtain error code call abbot sampler handler statu not allow execut command error code run time error encount run daili mainten procedur custom abl complet daili mainten th attempt instrument run issu occur c softwar version', 'custom state ap reseal aluminum coil list number l lot number rn would not seal appear wound incorrectli within cartridg result first use failur part replac coil resolv issu photo provid show evid failur', 'deform microparticl bottl observ use architect hiv ag ab combo reagent lot number', 'custom observ qualiti control level rang low use architect tsh reagent', 'custom observ microparticl clump resuspens issu architect anti hb', 'neg control high due aberr calibr use alin toxo igg calibr kit list number p lot number li', 'complaint text state calibr request sodium potassium chlorid remain process calibr statu screen even though qc run valid custom resolv process statu cycl power instrument recalibr sodium potassium chlorid custom alin system softwar v', 'custom observ low result biorad control use architect folat reagent lot ui result rang low qualiti control level custom recalibr new reagent lot issu resolv', 'custom call report order box ethanol reagent ln l lot fd box empti r wedg custom request replac product', 'custom complain unabl load calibr valu usb card use mcc lot fd list number e custom tri multipl time without success', 'custom observ non abbott control patient result shift high use architect bnp calibr lot k k k k', 'custom state one bottl mcc calibr ln e lot fd miss label', 'custom could not load ap reseal aluminum coil list number l reseal modul coil receiv without protect seal foil insid cartridg result first use failur part replac coil resolv issu', 'complaint text state softwar shutdown unexpectedli issu resolv reboot system i ...

# %% [markdown]
# ## Creating the Bag of Words model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 2].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state = 0)

# %% [markdown]
# ## Training the Naive Bayes model on the Training set

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train.astype(str))
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['No' 'No']
#  ['No' 'Yes']
#  ['No' 'No']
#  ['No' 'Yes']
#  ['No' 'Yes']
#  ['No' 'No']
#  ['No' 'No']
#  ['No' 'No']
#  ['No' nan]
#  ['No' 'No']]

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test.astype(str), y_pred)
print(cm)
accuracy_score(y_test.astype(str), y_pred)
# Out:
# [[6 0 0]
#  [3 0 0]
#  [1 0 0]]
# 0.6
